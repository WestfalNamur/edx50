# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
rolls = []
for i in range(1000000):
    rolls.append(random.choice([1,2,3,4,5,6]))
plt.hist(rolls, bins=np.linspace(0.5, 6.5, 7))
plt.show()

# %%
ys = []

for rep in range(1000000):
    y = 0
    for k in range(10):
        x = random.choice([1,2,3,4,5,6])
        y = y + x
    ys.append(y)
    
plt.hist(ys, bins=np.linspace(5.5, 60.5, 20))
plt.show()

# %% [markdown]
# Central Limit Theorem
#
# The sum of a large number of random variables, regardless of distribution, will approximately follow the normal distribution.

# %%
X = np.random.randint(1,7,(1000000,10))
Y = np.sum(X, axis=1)

plt.hist(ys, bins=np.linspace(5.5, 60.5, 20))
plt.show()

# %%
import time 
start_time = time.clock()

# %%
delta_X = np.random.normal(0, 1, (2,10000))
X_0 = np.array([[0], [0]])

X = np.concatenate((X_0, np.cumsum(delta_X, axis=1)), axis=1)

plt.plot(X[0], X[1], "-")
plt.show()

# %%
np.concatenate?
